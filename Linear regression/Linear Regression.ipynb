# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from math import sqrt

# %%
train_dataset = pd.read_csv('train.csv').values
test_dataset = pd.read_csv('test.csv').values
x_train = train_dataset[:,:1].reshape(-1)
y_train = train_dataset[:,1:2].reshape(-1)
x_test = test_dataset[:,:1].reshape(-1)
y_test = test_dataset[:,1:2].reshape(-1)

# %%
def gradient_descent(x,y):
    m_curr = b_curr = 0
    iterations = 100
    n = len(x)
    learning_rate = 0.0001
    
    plt.scatter(x_train,y_train , color = "green")
    for i in range(iterations):
        y_predicted = m_curr * x + b_curr
        plt.plot(x_train,y_predicted,color='red')
        cost = (1/n) * sum([val**2 for val in (y-y_predicted)])
        md = -(2/n)*sum(x*(y-y_predicted))
        bd = -(2/n)*sum(y-y_predicted)
        m_curr = m_curr - learning_rate * md
        b_curr = b_curr - learning_rate * bd
        print ("m {}, b {}, cost {} iteration {}".format(m_curr,b_curr,cost, i))
    return m_curr , b_curr

# %%
m , b = gradient_descent(x_train,y_train)
print(m,b)
residual_values = m*x_test+b - y_test
cost = (1/len(x_test)) * sum([val**2 for val in (y_test-(m*x_test+b))])
print(sqrt(cost))
plt.title('Variation of regression line')
plt.xlabel('x')
plt.ylabel('y')
plt.show()
# Out:
# m 0.6664335121426882, b 0.009982321691234279, cost 3336.652457734495 iteration 0
# m 0.8881789468519163, b 0.013299263844577925, cost 376.4275952761495 iteration 1
# m 0.961961352812457, b 0.014398405041591063, cost 48.69460832107487 iteration 2
# m 0.9865113664771447, b 0.014759607754196479, cost 12.410570180956396 iteration 3
# m 0.9946800687290679, b 0.014875273161060588, cost 8.393484336445717 iteration 4
# m 0.9973981448545797, b 0.014909240081898738, cost 7.948743544785666 iteration 5
# m 0.9983026100634536, b 0.014916023331063497, cost 7.899504908423312 iteration 6
# m 0.9986036244956616, b 0.014913761863582838, cost 7.894053183084638 iteration 7
# m 0.9987038500813611, b 0.014908491134094213, cost 7.893449202734698 iteration 8
# m 0.9987372663036322, b 0.0149022193460739, cost 7.8933819269048735 iteration 9
# m 0.9987484527478347, b 0.014895614697925939, cost 7.8933740708503946 iteration 10
# m 0.9987522425763691, b 0.014888899522246217, cost 7.893372793330448 iteration 11
# m 0.9987535712928973, b 0.01488214779673033, cost 7.893372244175363 iteration 12
# m 0.9987540811093596, b 0.014875384136292429, cost 7.893371775700045 iteration 13
# m 0.9987543184461906, b 0.014868616731150303, cost 7.893371316197822 iteration 14
# m 0.9987544651162756, b 0.014861848306459948, cost 7.893370857729912 iteration 15
# m 0.9987545816150198, b 0.014855079768963208, cost 7.893370399417361 iteration 16
# m 0.9987546880713267, b 0.014848311420352952, cost 7.893369941162897 iteration 17
# m 0.9987547911827754, b 0.01484154336100143, cost 7.893369482955702 iteration 18
# m 0.9987548931778812, b 0.014834775624294595, cost 7.893369024794609 iteration 19
# m 0.9987549947981481, b 0.01482800822132975, cost 7.893368566679452 iteration 20
# m 0.9987550962903, b 0.014821241155788, cost 7.893368108610236 iteration 21
# m 0.9987551977364306, b 0.014814474428882828, cost 7.893367650586962 iteration 22
# m 0.9987552991638556, b 0.014807708041006654, cost 7.893367192609584 iteration 23
# m 0.9987593518260081, b 0.01453733049798843, cost 7.893348911118771 iteration 63
# m 0.9987594530383865, b 0.014530578003937073, cost 7.89334845502028 iteration 64
# m 0.9987595542456909, b 0.014523825848405333, cost 7.893347998967511 iteration 65
# m 0.9987596554479216, b 0.014517074031376238, cost 7.893347542960462 iteration 66
# m 0.9987597566450787, b 0.014510322552832817, cost 7.893347086999144 iteration 67
# m 0.9987598578371625, b 0.0145035714127581, cost 7.8933466310835545 iteration 68
# m 0.9987599590241732, b 0.014496820611135119, cost 7.893346175213638 iteration 69
# m 0.9987600602061113, b 0.014490070147946909, cost 7.893345719389462 iteration 70
# m 0.9987601613829769, b 0.014483320023176502, cost 7.893345263610972 iteration 71
# m 0.9987602625547701, b 0.014476570236806931, cost 7.893344807878189 iteration 72
# m 0.9987603637214914, b 0.014469820788821232, cost 7.893344352191102 iteration 73
# m 0.998760464883141, b 0.014463071679202442, cost 7.893343896549676 iteration 74
# m 0.998760566039719, b 0.014456322907933595, cost 7.893343440953963 iteration 75
# m 0.9987606671912258, b 0.014449574474997734, cost 7.893342985403911 iteration 76
# m 0.9987607683376617, b 0.014442826380377893, cost 7.893342529899554 iteration 77
# m 0.9987608694790268, b 0.014436078624057111, cost 7.893342074440855 iteration 78
# m 0.9987609706153213, b 0.014429331206018432, cost 7.8933416190278205 iteration 79
# m 0.9987610717465458, b 0.014422584126244893, cost 7.893341163660439 iteration 80
# m 0.9987611728727002, b 0.014415837384719538, cost 7.893340708338728 iteration 81
# m 0.998761273993785, b 0.01440909098142541, cost 7.8933402530626555 iteration 82
# m 0.9987613751098002, b 0.014402344916345552, cost 7.893339797832258 iteration 83
# m 0.9987614762207463, b 0.01439559918946301, cost 7.89333934264747 iteration 84
# m 0.9987615773266234, b 0.014388853800760826, cost 7.89333888750832 iteration 85
# m 0.9987616784274319, b 0.014382108750222049, cost 7.89333843241483 iteration 86
# m 0.9987617795231719, b 0.014375364037829724, cost 7.893337977366959 iteration 87
# m 0.9987618806138437, b 0.0143686196635669, cost 7.89333752236471 iteration 88
# m 0.9987619816994476, b 0.014361875627416627, cost 7.893337067408069 iteration 89
# m 0.9987620827799839, b 0.014355131929361952, cost 7.893336612497056 iteration 90
# m 0.9987621838554527, b 0.014348388569385926, cost 7.893336157631659 iteration 91
# m 0.9987622849258543, b 0.014341645547471601, cost 7.893335702811849 iteration 92
# m 0.9987623859911889, b 0.014334902863602028, cost 7.8933352480376575 iteration 93
# m 0.9987624870514571, b 0.014328160517760263, cost 7.893334793309046 iteration 94
# m 0.9987625881066586, b 0.014321418509929356, cost 7.8933343386260475 iteration 95
# m 0.9987626891567941, b 0.014314676840092366, cost 7.893333883988631 iteration 96
# m 0.9987627902018638, b 0.014307935508232344, cost 7.893333429396787 iteration 97
# m 0.9987628912418677, b 0.014301194514332349, cost 7.8933329748505265 iteration 98
# m 0.9987629922768062, b 0.014294453858375437, cost 7.893332520349845 iteration 99
# 0.9987629922768062 0.014294453858375437
# 3.0759082445893284

# %%
plt.scatter(x_test , residual_values , color = "Orange")
plt.title('Residual Plot')
plt.xlabel('x value')
plt.ylabel('Residual value')
plt.show()
